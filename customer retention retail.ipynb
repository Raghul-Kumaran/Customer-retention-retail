# %% [markdown]
# # Importing Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as s
import matplotlib.pyplot as plt
#sns.set(style = 'whitegrid')
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import classification_report
from sklearn.feature_selection import RFE
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from sklearn.linear_model import LogisticRegression

from sklearn.preprocessing import StandardScaler

import statsmodels.api as sm

from sklearn.metrics import confusion_matrix,precision_score,f1_score,cohen_kappa_score,accuracy_score

from sklearn.tree import DecisionTreeClassifier,export_graphviz
from sklearn.metrics import plot_confusion_matrix,plot_roc_curve,roc_auc_score,roc_curve

from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,StackingClassifier




from IPython.display import Image

from sklearn.model_selection import GridSearchCV,RandomizedSearchCV, cross_val_score

from statsmodels.stats.outliers_influence import variance_inflation_factor


from xgboost import XGBClassifier

# %%
# set the plot size using 'rcParams'
# once the plot size is set using 'rcParams', it sets the size of all the forthcoming plots in the file
# pass width and height in inches to 'figure.figsize' 
plt.rcParams['figure.figsize'] = [15,8]

# %% [markdown]
# # 1. Data understanding

# %%
df = pd.read_excel('storedata_total.xlsx')
df.head()
# Out:
#    custid  retained    created           firstorder            lastorder  \
# 0  6H6T6N         0 2012-09-28  2013-08-11 00:00:00  2013-08-11 00:00:00
# 1  APCENR         1 2010-12-19  2011-04-01 00:00:00  2014-01-19 00:00:00
# 2  7UP6MS         0 2010-10-03  2010-12-01 00:00:00  2011-07-06 00:00:00
# 3  7ZEW8G         0 2010-10-22  2011-03-28 00:00:00  2011-03-28 00:00:00
# 4  8V726M         1 2010-11-27  2010-11-29 00:00:00  2013-01-28 00:00:00
#
#    esent   eopenrate  eclickrate  avgorder   ordfreq  paperless  refill  \
# 0     29  100.000000    3.448276     14.52  0.000000          0       0
# 1     95   92.631579   10.526316     83.69  0.181641          1       1
# 2      0    0.000000    0.000000     33.58  0.059908          0       0
# 3      0    0.000000    0.000000     54.96  0.000000          0       0
# 4     30   90.000000   13.333333    111.91  0.008850          0       0
#
#    doorstep     favday city
# 0         0     Monday  DEL
# 1         1     Friday  DEL
# 2         0  Wednesday  DEL
# 3         0   Thursday  BOM
# 4         0     Monday  BOM

# %%
# Checking the shape of Dataframe
df.shape
# Out:
# (30801, 15)

# %%
# Checking the data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30801 entries, 0 to 30800
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   custid      30781 non-null  object
#  1   retained    30801 non-null  int64
#  2   created     30781 non-null  datetime64[ns]
#  3   firstorder  30781 non-null  object
#  4   lastorder   30781 non-null  object
#  5   esent       30801 non-null  int64
#  6   eopenrate   30801 non-null  float64
#  7   eclickrate  30801 non-null  float64
#  8   avgorder    30801 non-null  float64
#  9   ordfreq     30801 non-null  float64
#  10  paperless   30801 non-null  int64
#  11  refill      30801 non-null  int64
#  12  doorstep    30801 non-null  int64
#  13  favday      30801 non-null  object
#  14  city        30801 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(5), object(5)
# memory usage: 3.5+ MB

# %%
# checking the null value 
df.isnull().sum()
# Out:
# custid        20
# retained       0
# created       20
# firstorder    20
# lastorder     20
# esent          0
# eopenrate      0
# eclickrate     0
# avgorder       0
# ordfreq        0
# paperless      0
# refill         0
# doorstep       0
# favday         0
# city           0
# dtype: int64

# %%
# removing the null values

# %%
df.drop(index = df[df['lastorder'].isnull()].index.tolist(), axis = 0, inplace = True)
df.drop(index = df[df['firstorder'].isnull()].index.tolist(), axis = 0, inplace = True)

# %%
df.shape
# Out:
# (30781, 15)

# %%
df['firstorder'] = df['firstorder'].astype(str)
df['lastorder'] = df['lastorder'].astype(str)

# %%
df['firstorder'] = df['firstorder'].str[:10] 
df['lastorder'] = df['lastorder'].str[:10]

# %%
df.drop(index = df[df['firstorder'] == '1/0/00'].index.tolist(), axis = 0, inplace =True)
df.drop(index = df[df['lastorder'] == '1/0/00'].index.tolist(), axis = 0, inplace =True)
df.drop(index = df[df['firstorder'] == '00:00:00'].index.tolist(), axis = 0, inplace =True)
df.drop(index = df[df['lastorder'] == '00:00:00'].index.tolist(), axis = 0, inplace =True)

# %%
df.shape
# Out:
# (30747, 15)

# %%
from datetime import datetime
df['firstorder'] = df['firstorder'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d'))
df['lastorder'] = df['lastorder'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30747 entries, 0 to 30800
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   custid      30747 non-null  object
#  1   retained    30747 non-null  int64
#  2   created     30747 non-null  datetime64[ns]
#  3   firstorder  30747 non-null  datetime64[ns]
#  4   lastorder   30747 non-null  datetime64[ns]
#  5   esent       30747 non-null  int64
#  6   eopenrate   30747 non-null  float64
#  7   eclickrate  30747 non-null  float64
#  8   avgorder    30747 non-null  float64
#  9   ordfreq     30747 non-null  float64
#  10  paperless   30747 non-null  int64
#  11  refill      30747 non-null  int64
#  12  doorstep    30747 non-null  int64
#  13  favday      30747 non-null  object
#  14  city        30747 non-null  object
# dtypes: datetime64[ns](3), float64(4), int64(5), object(3)
# memory usage: 3.8+ MB

# %%
df_num = df.select_dtypes(include=np.number)
df_num.columns
# Out:
# Index(['retained', 'esent', 'eopenrate', 'eclickrate', 'avgorder', 'ordfreq',
#        'paperless', 'refill', 'doorstep'],
#       dtype='object')

# %%
df_cat = df.select_dtypes(include=object)
df_cat.columns
# Out:
# Index(['custid', 'favday', 'city'], dtype='object')

# %%
df.describe()
# Out:
#            retained         esent     eopenrate    eclickrate      avgorder  \
# count  30747.000000  30747.000000  30747.000000  30747.000000  30747.000000
# mean       0.794647     28.137314     25.559618      5.676134     61.848928
# std        0.403966     16.751679     29.558790     10.567226     40.956758
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.000000     16.000000      2.083333      0.000000     40.020000
# 50%        1.000000     32.000000     13.207547      0.000000     50.960000
# 75%        1.000000     42.000000     40.000000      7.142857     74.260000
# max        1.000000    291.000000    100.000000    100.000000   2600.140000
#
#             ordfreq     paperless        refill      doorstep
# count  30747.000000  30747.000000  30747.000000  30747.000000
# mean       0.037769      0.649234      0.095034      0.038931
# std        0.103998      0.477218      0.293266      0.193433
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      1.000000      0.000000      0.000000
# 75%        0.040917      1.000000      0.000000      0.000000
# max        3.250000      1.000000      1.000000      1.000000

# %%
# max value in esent  which could be a outlier
# avgorder could have potential outliers

# %%
# consider only the target variable
df_target = df['retained'].copy()

# get counts of 0's and 1's in the 'Chance of Admit' variable
df_target.value_counts()

# plot the countplot of the variable 'Chance of Admit'
sns.countplot(x = df_target)

# use below code to print the values in the graph
# 'x' and 'y' gives position of the text
# 's' is the text 
plt.text(x = -0.05, y = df_target.value_counts()[0] + 1, s = str(round((df_target.value_counts()[0])*100/len(df_target),2)) + '%')
plt.text(x = 0.95, y = df_target.value_counts()[1] +1, s = str(round((df_target.value_counts()[1])*100/len(df_target),2)) + '%')

# add plot and axes labels
# set text size using 'fontsize'
plt.title('Count Plot for Target Variable (retained)', fontsize = 15)
plt.xlabel('Target Variable', fontsize = 15)
plt.ylabel('Count', fontsize = 15)

# to show the plot
plt.show()

# %%
# The data is imbalance

# %% [markdown]
# ## Remove Insignificant Variables

# %% [markdown]
# The column `custid` contains the serial number of the customer, which is redundant for further analysis. Thus, we drop the column.

# %%
# 'axis = 1' drops the specified column
df = df.drop('custid',axis=1)

# %%
# for the independent numeric variables, we plot the histogram to check the distribution of the variables
# Note: the hist() function considers the numeric variables only, by default
# we drop the target variable using drop()
# 'axis=1' drops the specified column
df.drop('retained', axis = 1).hist()

# adjust the subplots
plt.tight_layout()

# display the plot
plt.show()  

# print the skewness for each numeric independent variable
print('Skewness:')
# we drop the target variable using drop()
# 'axis=1' drops the specified column
# skew() returns the coefficient of skewness for each variable
df.drop('retained', axis = 1).skew()
# Out:
# Skewness:
# esent         -0.052546
# eopenrate      1.165951
# eclickrate     3.895510
# avgorder      11.703889
# ordfreq       10.465979
# paperless     -0.625475
# refill         2.761946
# doorstep       4.767540
# dtype: float64

# %% [markdown]
# **Interpretation:** The above plot indicates that all the variables are not  normally distributed.

# %%
# sort the variables on the basis of total null values in the variable
# 'isnull().sum()' returns the number of missing values in each variable
# 'ascending = False' sorts values in the descending order
# the variable with highest number of missing values will appear first
Total = df.isnull().sum().sort_values(ascending=False)          

# calculate percentage of missing values
# 'ascending = False' sorts values in the descending order
# the variable with highest percentage of missing values will appear first
Percent = (df.isnull().sum()*100/df.isnull().count()).sort_values(ascending=False)   

# concat the 'Total' and 'Percent' columns using 'concat' function
# pass a list of column names in parameter 'keys' 
# 'axis = 1' concats along the columns
missing_data = pd.concat([Total, Percent], axis = 1, keys = ['Total', 'Percentage of Missing Values'])    
missing_data
# Out:
#             Total  Percentage of Missing Values
# retained        0                           0.0
# created         0                           0.0
# firstorder      0                           0.0
# lastorder       0                           0.0
# esent           0                           0.0
# eopenrate       0                           0.0
# eclickrate      0                           0.0
# avgorder        0                           0.0
# ordfreq         0                           0.0
# paperless       0                           0.0
# refill          0                           0.0
# doorstep        0                           0.0
# favday          0                           0.0
# city            0                           0.0

# %%
# null values is been removed earlier

# %%
df.describe()
# Out:
#            retained         esent     eopenrate    eclickrate      avgorder  \
# count  30747.000000  30747.000000  30747.000000  30747.000000  30747.000000
# mean       0.794647     28.137314     25.559618      5.676134     61.848928
# std        0.403966     16.751679     29.558790     10.567226     40.956758
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.000000     16.000000      2.083333      0.000000     40.020000
# 50%        1.000000     32.000000     13.207547      0.000000     50.960000
# 75%        1.000000     42.000000     40.000000      7.142857     74.260000
# max        1.000000    291.000000    100.000000    100.000000   2600.140000
#
#             ordfreq     paperless        refill      doorstep
# count  30747.000000  30747.000000  30747.000000  30747.000000
# mean       0.037769      0.649234      0.095034      0.038931
# std        0.103998      0.477218      0.293266      0.193433
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      1.000000      0.000000      0.000000
# 75%        0.040917      1.000000      0.000000      0.000000
# max        3.250000      1.000000      1.000000      1.000000

# %%
df.head()
# Out:
#    retained    created firstorder  lastorder  esent   eopenrate  eclickrate  \
# 0         0 2012-09-28 2013-08-11 2013-08-11     29  100.000000    3.448276
# 1         1 2010-12-19 2011-04-01 2014-01-19     95   92.631579   10.526316
# 2         0 2010-10-03 2010-12-01 2011-07-06      0    0.000000    0.000000
# 3         0 2010-10-22 2011-03-28 2011-03-28      0    0.000000    0.000000
# 4         1 2010-11-27 2010-11-29 2013-01-28     30   90.000000   13.333333
#
#    avgorder   ordfreq  paperless  refill  doorstep     favday city
# 0     14.52  0.000000          0       0         0     Monday  DEL
# 1     83.69  0.181641          1       1         1     Friday  DEL
# 2     33.58  0.059908          0       0         0  Wednesday  DEL
# 3     54.96  0.000000          0       0         0   Thursday  BOM
# 4    111.91  0.008850          0       0         0     Monday  BOM

# %% [markdown]
# ### Outlier Treatment

# %%
# using kde and subplot to check the normality and outliers 
plt.figure(figsize=(15,10))
plt.subplot(2,3,1)
sns.kdeplot(df.esent,color='red');
plt.subplot(2,3,2)
sns.kdeplot(df.eclickrate,color='green')
plt.subplot(2,3,3)
sns.kdeplot(df.avgorder,color='black')
plt.subplot(2,3,4)
sns.kdeplot(df.eopenrate,color='blue')

plt.show()

# %%
# ploting the boxplot to check whether their are outliers present or not
# using subplot tp plot the boxplot
plt.figure(figsize=(15,10))
plt.subplot(2,3,1)
sns.boxplot(x = df.esent,color='red');
plt.subplot(2,3,2)
sns.boxplot(x = df.eclickrate,color='green')
plt.subplot(2,3,3)
sns.boxplot(x = df.avgorder,color='pink')
plt.subplot(2,3,4)
sns.boxplot(df.eopenrate,color='blue')
plt.show()

# %%
# creating a function to impute IQR in the particular column
def impute(x):
    for i in x.columns:
        iqr = 1.5*(x[i].quantile(0.75) - x[i].quantile(0.25))
        ul = x[i].quantile(0.75) + iqr
        ll = x[i].quantile(0.25) - iqr
        temp = []
        for j in x[i].index:
            if x[i][j] > ul or x[i][j] < ll :
                temp.append(np.median(x[i]))
            elif x[i][j] < 0:
                temp.append(0)
            else:
                temp.append(x[i][j])
        x[i]= temp
    return x

# %%
# imputing the IQR
df[['esent','eclickrate','avgorder','eopenrate']] = impute(df[['esent','eclickrate','avgorder','eopenrate',]])

# %%
# ploting the boxplot to check whether their are outliers present or not
plt.figure(figsize=(15,10))
plt.subplot(2,3,1)
sns.boxplot(x = df.esent,color='red');
plt.subplot(2,3,2)
sns.boxplot(x = df.eclickrate,color='green')
plt.subplot(2,3,3)
sns.boxplot(x = df.avgorder,color='pink')
plt.subplot(2,3,4)
sns.boxplot(df.eopenrate,color='blue')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,3,1)
sns.kdeplot(df.esent,color='red');
plt.subplot(2,3,2)
sns.kdeplot(df.eclickrate,color='green')
plt.subplot(2,3,3)
sns.kdeplot(df.avgorder,color='black')
#plt.subplot(2,3,4)
#sns.kdeplot(df.ordfreq,color='orange')
plt.subplot(2,3,4)
sns.kdeplot(df.eopenrate,color='blue')
plt.show()

# %%
df.describe()
# Out:
#            retained         esent     eopenrate    eclickrate      avgorder  \
# count  30747.000000  30747.000000  30747.000000  30747.000000  30747.000000
# mean       0.794647     28.090480     22.229742      2.778352     54.948481
# std        0.403966     16.505522     25.616478      4.314645     22.565924
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.000000     16.000000      2.083333      0.000000     40.020000
# 50%        1.000000     32.000000     13.207547      0.000000     50.960000
# 75%        1.000000     42.000000     34.210526      4.444444     66.020000
# max        1.000000     80.000000     96.875000     17.777778    125.620000
#
#             ordfreq     paperless        refill      doorstep
# count  30747.000000  30747.000000  30747.000000  30747.000000
# mean       0.037769      0.649234      0.095034      0.038931
# std        0.103998      0.477218      0.293266      0.193433
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      1.000000      0.000000      0.000000
# 75%        0.040917      1.000000      0.000000      0.000000
# max        3.250000      1.000000      1.000000      1.000000

# %%
# creating the two column to find the difference of when the account created to first order 
# creating the two column to find the difference of when the first orderr to last order 
df['create_first'] = df.firstorder - df.created
df['create_first'] = df['create_first']/np.timedelta64(1,'D')
df['first_last'] = df.lastorder - df.firstorder
df['first_last'] = df['first_last']/np.timedelta64(1,'D')

# %%
# droping the firstorder,lastorder,created from the dataframe 
df = df.drop(['firstorder','lastorder','created'],axis=1)

# %%
df.head(20)
# Out:
#     retained  esent  eopenrate  eclickrate  avgorder   ordfreq  paperless  \
# 0          0   29.0  13.207547    3.448276     14.52  0.000000          0
# 1          1   32.0  92.631579   10.526316     83.69  0.181641          1
# 2          0    0.0   0.000000    0.000000     33.58  0.059908          0
# 3          0    0.0   0.000000    0.000000     54.96  0.000000          0
# 4          1   30.0  90.000000   13.333333    111.91  0.008850          0
# 5          1   46.0  80.434783   15.217391     50.96  0.141176          1
# 6          1   60.0  43.333333    6.666667    116.55  0.125000          0
# 7          1   64.0  28.125000   15.625000     68.10  0.040094          1
# 8          1   45.0   0.000000    0.000000     46.60  0.000000          0
# 9          1   34.0  94.117647    8.823529     66.07  0.133789          1
# 10         1   48.0  83.333333    2.083333     89.04  0.086655          0
# 11         1   40.0  87.500000    0.000000     88.30  0.088477          0
# 12         1   69.0   2.898551    2.898551     50.96  0.059432          1
# 13         1   38.0  36.842105    0.000000    116.77  0.078947          0
# 14         0   16.0  12.500000    0.000000     59.25  0.129353          1
# 15         1   45.0  60.000000   15.555556     49.73  0.044248          1
# 16         0   13.0  61.538462   15.384615     50.96  0.119114          1
# 17         1   48.0   8.333333    2.083333    101.06  0.037801          0
# 18         1   57.0  17.543860    0.000000     14.02  0.066010          0
# 19         1   46.0  65.217391    8.695652     79.39  0.069838          1
#
#     refill  doorstep     favday city  create_first  first_last
# 0        0         0     Monday  DEL         317.0         0.0
# 1        1         1     Friday  DEL         103.0      1024.0
# 2        0         0  Wednesday  DEL          59.0       217.0
# 3        0         0   Thursday  BOM         157.0         0.0
# 4        0         0     Monday  BOM           2.0       791.0
# 5        1         0  Wednesday  DEL         694.0      1190.0
# 6        1         0     Friday  BOM         112.0       976.0
# 7        1         0     Friday  DEL         656.0       848.0
# 8        0         0  Wednesday  DEL          52.0         0.0
# 9        0         0     Monday  DEL          53.0      1024.0
# 10       0         1     Friday  DEL          57.0      1154.0
# 11       0         0  Wednesday  DEL         539.0       972.0
# 12       1         1     Monday  DEL         478.0      1161.0
# 13       0         0    Tuesday  DEL         352.0       950.0
# 14       1         0    Tuesday  DEL           3.0      1005.0
# 15       1         0  Wednesday  BOM          19.0      1017.0
# 16       0         0     Monday  DEL         115.0      1083.0
# 17       0         0     Monday  DEL         560.0       582.0
# 18       0         0     Monday  BOM          67.0      1015.0
# 19       0         0   Thursday  DEL         231.0       988.0

# %% [markdown]
# ## Data visualization (EDA)

# %%
# Using countplot to check the favorite delivery day
plt.figure(figsize=(15,7))
sns.countplot(x = df.favday)
plt.show()

# %%
#The number of orders delivered are highest on Monday and Tuesday since the number
# of orders placed are maximum on Saturday and Sunday.

# %%
sns.barplot(x=df['retained'],y=df['first_last']);

# %%
pd.crosstab(index=df.city,columns=df.retained).plot(kind='bar',figsize=(15,8))
plt.show()

# %%
# The retention rate is maximum in Bombay because of high population and rainy climatic conditions. 
# Bangalore has the least retention rate because people in Bangalore prefer coffee over tea.

# %%
plt.figure(figsize=(15,7))
sns.countplot(x = df.city)
plt.show()

# %%
# most of the orders are placed from the bombay city
# bangalore has the least order

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(x= df.esent, y = df.eclickrate, hue= df.retained)
plt.show()

# %%
# The greater the emails sent(esent) the eclickrate goes down.

# %%
sns.barplot(x=df.esent,y=df.retained)
# Out:
# <AxesSubplot:xlabel='esent', ylabel='retained'>

# %%
# As esent increases customers are likely to be retained

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(x= df.eclickrate, y = df.eopenrate, hue= df.retained)
plt.show()

# %%
# As esent increases customers are likely to be retained

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True,annot_kws={'size':15}, cmap = 'gist_earth');

# %%
# esent is highly  + correlated with retained
# Paperless and avgorder are - ve correlation

# %%
df.shape
# Out:
# (30747, 13)

# %%
X = df.drop('retained',axis=1)
Y = df.retained
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(X,Y,test_size=0.3,random_state=12)

# %%
xtrain.head()
# Out:
#        esent  eopenrate  eclickrate  avgorder   ordfreq  paperless  refill  \
# 17332   35.0   2.857143    0.000000     37.94  0.214286          1       0
# 29084   35.0   2.857143    0.000000     36.80  0.151515          1       0
# 2034    43.0  27.906977    0.000000     63.92  0.109164          1       0
# 19441   33.0   9.090909    3.030303     40.25  0.000000          1       0
# 6591     0.0   0.000000    0.000000     75.81  0.016129          0       0
#
#        doorstep    favday city  create_first  first_last
# 17332         0  Thursday  DEL           0.0        14.0
# 29084         0    Monday  MAA           0.0        33.0
# 2034          0    Monday  DEL         443.0       742.0
# 19441         0  Thursday  DEL           0.0         0.0
# 6591          0    Monday  BOM           0.0       124.0

# %%
xtrain.shape
# Out:
# (21522, 12)

# %%
xtest.shape
# Out:
# (9225, 12)

# %%
xtest.head()
# Out:
#        esent  eopenrate  eclickrate  avgorder   ordfreq  paperless  refill  \
# 30213   63.0  68.253968         0.0     96.71  0.233333          1       0
# 13118    4.0  25.000000         0.0     50.96  0.000000          1       0
# 11120   20.0  30.000000        15.0     50.59  0.222222          0       0
# 7695    40.0  40.000000        15.0     98.16  0.125000          1       0
# 9813    18.0   0.000000         0.0    120.45  0.058824          1       0
#
#        doorstep    favday city  create_first  first_last
# 30213         1  Saturday  MAA          83.0        30.0
# 13118         0    Friday  DEL           1.0         0.0
# 11120         0   Tuesday  BOM        1014.0         9.0
# 7695          0   Tuesday  DEL        1427.0        16.0
# 9813          0   Tuesday  DEL           0.0       102.0

# %% [markdown]
# ### Transformation

# %%
import scipy.stats as s

# %%
# Using boxcox to

# %%
xtrain['avgorder'] = s.boxcox(xtrain.avgorder+1)[0]
xtrain['esent'] = s.boxcox(xtrain.esent+1)[0]
xtrain['eopenrate'] = s.boxcox(xtrain.eopenrate+1)[0]
xtrain['eclickrate'] = s.boxcox(xtrain.eclickrate+1)[0]
xtrain['create_first'] = s.boxcox(abs(xtrain.create_first)+1)[0]
xtrain['first_last'] = s.boxcox(xtrain.first_last+5)[0]

# %%
xtrain.head()
# Out:
#            esent  eopenrate  eclickrate   avgorder   ordfreq  paperless  \
# 17332  23.385315   1.493100    0.000000   8.812655  0.214286          1
# 29084  23.385315   1.493100    0.000000   8.672427  0.151515          1
# 2034   27.936726   4.351149    0.000000  11.524373  0.109164          1
# 19441  22.224295   2.752666    0.873786   9.089739  0.000000          1
# 6591    0.000000   0.000000    0.000000  12.553521  0.016129          0
#
#        refill  doorstep    favday city  create_first  first_last
# 17332       0         0  Thursday  DEL      0.000000    1.390604
# 29084       0         0    Monday  MAA      0.000000    1.489425
# 2034        0         0    Monday  DEL      2.794496    1.650334
# 19441       0         0  Thursday  DEL      0.000000    1.036295
# 6591        0         0    Monday  BOM      0.000000    1.589549

# %%
xtest['avgorder'] = s.boxcox(xtest.avgorder+1)[0]
xtest['esent'] = s.boxcox(xtest.esent+1)[0]
xtest['eopenrate'] = s.boxcox(xtest.eopenrate+1)[0]
xtest['eclickrate'] = s.boxcox(xtest.eclickrate+1)[0]
xtest['create_first'] = s.boxcox(abs(xtest.create_first)+1)[0]
xtest['first_last'] = s.boxcox(xtest.first_last+5)[0]

# %%
xtest.head()
# Out:
#            esent  eopenrate  eclickrate   avgorder   ordfreq  paperless  \
# 30213  40.120198   5.789098    0.000000  14.111987  0.233333          1
# 13118   3.470332   4.130372    0.000000  10.240801  0.000000          1
# 11120  14.709258   4.411637    1.193006  10.202661  0.222222          0
# 7695   27.013450   4.873249    1.193006  14.215244  0.125000          1
# 9813   13.403383   0.000000    0.000000  15.704155  0.058824          1
#
#        refill  doorstep    favday city  create_first  first_last
# 30213       0         1  Saturday  MAA      2.476752    1.463088
# 13118       0         0    Friday  DEL      0.627079    1.029650
# 11120       0         0   Tuesday  BOM      2.956834    1.319954
# 7695        0         0   Tuesday  DEL      2.999263    1.393097
# 9813        0         0   Tuesday  DEL      0.000000    1.558169

# %%
xtest.describe()
# Out:
#              esent    eopenrate   eclickrate     avgorder      ordfreq  \
# count  9225.000000  9225.000000  9225.000000  9225.000000  9225.000000
# mean     19.295005     2.888699     0.410671    10.382463     0.037144
# std      10.731860     2.084649     0.502041     2.186513     0.106525
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      12.077757     1.128921     0.000000     9.038430     0.000000
# 50%      22.226624     3.175222     0.000000    10.236686     0.000000
# 75%      28.188407     4.578164     0.974692    11.661418     0.039062
# max      48.828580     6.431394     1.213178    16.018454     2.142857
#
#          paperless       refill     doorstep  create_first   first_last
# count  9225.000000  9225.000000  9225.000000   9225.000000  9225.000000
# mean      0.652033     0.093008     0.037398      1.042516     1.216164
# std       0.476351     0.290460     0.189746      1.052573     0.246853
# min       0.000000     0.000000     0.000000      0.000000     1.029650
# 25%       0.000000     0.000000     0.000000      0.000000     1.029650
# 50%       1.000000     0.000000     0.000000      0.627079     1.029650
# 75%       1.000000     0.000000     0.000000      2.096179     1.498709
# max       1.000000     1.000000     1.000000      3.037104     1.639704

# %%
xtrain.describe()
# Out:
#               esent     eopenrate    eclickrate      avgorder       ordfreq  \
# count  21522.000000  21522.000000  21522.000000  21522.000000  21522.000000
# mean      18.705701      2.944819      0.408253     10.422846      0.038038
# std       10.437589      2.114319      0.500795      2.210037      0.102898
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       11.179582      1.224508      0.000000      9.062557      0.000000
# 50%       21.639892      3.245455      0.000000     10.270222      0.000000
# 75%       27.375217      4.682847      0.971140     11.718040      0.041667
# max       47.644262      6.540736      1.206786     16.085289      3.250000
#
#           paperless        refill      doorstep  create_first    first_last
# count  21522.000000  21522.000000  21522.000000  21522.000000  21522.000000
# mean       0.648035      0.095902      0.039587      1.025041      1.229502
# std        0.477594      0.294463      0.194992      1.040803      0.253888
# min        0.000000      0.000000      0.000000      0.000000      1.036295
# 25%        0.000000      0.000000      0.000000      0.000000      1.036295
# 50%        1.000000      0.000000      0.000000      0.625706      1.036295
# 75%        1.000000      0.000000      0.000000      2.077454      1.520531
# max        1.000000      1.000000      1.000000      2.983873      1.664922

# %% [markdown]
# ### Scaling

# %%
SS = StandardScaler()

# %%
a = SS.fit_transform(xtrain[['eclickrate','eopenrate','eclickrate','avgorder','esent','create_first','first_last']])

# %%
xtrain['eclickrate'] = a[:,0]
xtrain['eopenrate'] = a[:,1]
xtrain['eclickrate'] = a[:,2]
xtrain['avgorder'] = a[:,3]
xtrain['esent'] = a[:,4]
xtrain['create_first'] = a[:,5]
xtrain['first_last'] = a[:,6]

# %%
xtrain.head()
# Out:
#           esent  eopenrate  eclickrate  avgorder   ordfreq  paperless  refill  \
# 17332  0.448353  -0.686629   -0.815228 -0.728598  0.214286          1       0
# 29084  0.448353  -0.686629   -0.815228 -0.792050  0.151515          1       0
# 2034   0.884423   0.665161   -0.815228  0.498432  0.109164          1       0
# 19441  0.337116  -0.090884    0.929610 -0.603220  0.000000          1       0
# 6591  -1.792189  -1.392830   -0.815228  0.964113  0.016129          0       0
#
#        doorstep    favday city  create_first  first_last
# 17332         0  Thursday  DEL     -0.984879    0.634553
# 29084         0    Monday  MAA     -0.984879    1.023795
# 2034          0    Monday  DEL      1.700125    1.657588
# 19441         0  Thursday  DEL     -0.984879   -0.761014
# 6591          0    Monday  BOM     -0.984879    1.418168

# %%
b = SS.transform(xtest[['eclickrate','eopenrate','eclickrate','avgorder','esent','create_first','first_last']])
b
# Out:
# array([[-0.81522789,  1.34527696, -0.81522789, ...,  2.05171856,
#          1.39483085,  0.92005849],
#        [-0.81522789,  0.56073858, -0.81522789, ..., -1.45969752,
#         -0.38237012, -0.78718578],
#        [ 1.56705082,  0.69377003,  1.56705082, ..., -0.38289833,
#          1.8561032 ,  0.35627678],
#        ...,
#        [-0.81522789, -0.49876326, -0.81522789, ...,  1.13148961,
#          0.80907939,  0.79061416],
#        [-0.81522789, -1.3928303 , -0.81522789, ...,  0.45334903,
#         -0.98487948, -0.78718578],
#        [ 1.25678324,  0.05494615,  1.25678324, ..., -0.57126678,
#         -0.98487948, -0.78718578]])

# %%
xtest['eclickrate'] = b[:,0]
xtest['eopenrate'] = b[:,1]
xtest['eclickrate'] = b[:,2]
xtest['avgorder'] = b[:,3]
xtest['esent'] = b[:,4]
xtest['create_first'] = b[:,5]
xtest['first_last'] = b[:,6]

# %%
xtest.head()
# Out:
#           esent  eopenrate  eclickrate  avgorder   ordfreq  paperless  refill  \
# 30213  2.051719   1.345277   -0.815228  1.669305  0.233333          1       0
# 13118 -1.459698   0.560739   -0.815228 -0.082374  0.000000          1       0
# 11120 -0.382898   0.693770    1.567051 -0.099632  0.222222          0       0
# 7695   0.795964   0.912102    1.567051  1.716029  0.125000          1       0
# 9813  -0.508014  -1.392830   -0.815228  2.389748  0.058824          1       0
#
#        doorstep    favday city  create_first  first_last
# 30213         1  Saturday  MAA      1.394831    0.920058
# 13118         0    Friday  DEL     -0.382370   -0.787186
# 11120         0   Tuesday  BOM      1.856103    0.356277
# 7695          0   Tuesday  DEL      1.896870    0.644375
# 9813          0   Tuesday  DEL     -0.984879    1.294566

# %% [markdown]
# ### Encoding the categorical columns

# %%
# Using dummy emcoding to encode the categorical columns

# %%
xtrain = pd.concat((xtrain.drop(columns=['city','favday'],axis=1),pd.get_dummies(xtrain[['favday','city']],drop_first=True)),
                   axis=1)

# %%
xtrain.head()
# Out:
#           esent  eopenrate  eclickrate  avgorder   ordfreq  paperless  refill  \
# 17332  0.448353  -0.686629   -0.815228 -0.728598  0.214286          1       0
# 29084  0.448353  -0.686629   -0.815228 -0.792050  0.151515          1       0
# 2034   0.884423   0.665161   -0.815228  0.498432  0.109164          1       0
# 19441  0.337116  -0.090884    0.929610 -0.603220  0.000000          1       0
# 6591  -1.792189  -1.392830   -0.815228  0.964113  0.016129          0       0
#
#        doorstep  create_first  first_last  favday_Monday  favday_Saturday  \
# 17332         0     -0.984879    0.634553              0                0
# 29084         0     -0.984879    1.023795              1                0
# 2034          0      1.700125    1.657588              1                0
# 19441         0     -0.984879   -0.761014              0                0
# 6591          0     -0.984879    1.418168              1                0
#
#        favday_Sunday  favday_Thursday  favday_Tuesday  favday_Wednesday  \
# 17332              0                1               0                 0
# 29084              0                0               0                 0
# 2034               0                0               0                 0
# 19441              0                1               0                 0
# 6591               0                0               0                 0
#
#        city_BOM  city_DEL  city_MAA
# 17332         0         1         0
# 29084         0         0         1
# 2034          0         1         0
# 19441         0         1         0
# 6591          1         0         0

# %%
xtest = pd.concat((xtest.drop(columns=['city','favday'],axis=1),pd.get_dummies(xtest[['favday','city']],drop_first=True))
                  ,axis=1)

# %%
xtest.head()
# Out:
#           esent  eopenrate  eclickrate  avgorder   ordfreq  paperless  refill  \
# 30213  2.051719   1.345277   -0.815228  1.669305  0.233333          1       0
# 13118 -1.459698   0.560739   -0.815228 -0.082374  0.000000          1       0
# 11120 -0.382898   0.693770    1.567051 -0.099632  0.222222          0       0
# 7695   0.795964   0.912102    1.567051  1.716029  0.125000          1       0
# 9813  -0.508014  -1.392830   -0.815228  2.389748  0.058824          1       0
#
#        doorstep  create_first  first_last  favday_Monday  favday_Saturday  \
# 30213         1      1.394831    0.920058              0                1
# 13118         0     -0.382370   -0.787186              0                0
# 11120         0      1.856103    0.356277              0                0
# 7695          0      1.896870    0.644375              0                0
# 9813          0     -0.984879    1.294566              0                0
#
#        favday_Sunday  favday_Thursday  favday_Tuesday  favday_Wednesday  \
# 30213              0                0               0                 0
# 13118              0                0               0                 0
# 11120              0                0               1                 0
# 7695               0                0               1                 0
# 9813               0                0               1                 0
#
#        city_BOM  city_DEL  city_MAA
# 30213         0         0         1
# 13118         0         1         0
# 11120         1         0         0
# 7695          0         1         0
# 9813          0         1         0

# %%
xtrain.to_csv('train.csv')

# %%
xtest.to_csv('test.csv')

# %% [markdown]
# ### Balancing the data

# %%
xtrain.shape
# Out:
# (21522, 19)

# %%
ytrain.shape
# Out:
# (21522,)

# %%
from imblearn.combine import SMOTEENN

# %%
xtrain_bal,ytrain_bal = SMOTEENN().fit_resample(xtrain,ytrain)

# %%
ytrain_bal.value_counts().plot(kind='bar')
plt.text(x = -0.05, y = ytrain_bal.value_counts()[0] + 1, s = str(round((ytrain_bal.value_counts()[0])*100/len(ytrain_bal),2)) + '%')
plt.text(x = 0.95, y = ytrain_bal.value_counts()[1] +1, s = str(round((ytrain_bal.value_counts()[1])*100/len(ytrain_bal),2)) + '%')

# add plot and axes labels
# set text size using 'fontsize'
plt.title('Count Plot for Target Variable (retained)', fontsize = 15)
plt.xlabel('Target Variable', fontsize = 15)
plt.ylabel('Count', fontsize = 15)

# to show the plot
plt.show()

# %%
# The data is balanced

# %%
import  scipy.stats as stats

# %% [markdown]
# ## Base model

# %%
print(xtrain_bal.shape)
print(ytrain_bal.shape)
# Out:
# (30895, 19)
# (30895,)

# %%
# Logestic regression 
log_reg = sm.Logit(ytrain_bal,xtrain_bal).fit()
print(log_reg.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.133064
#          Iterations 9
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               retained   No. Observations:                30895
# Model:                          Logit   Df Residuals:                    30876
# Method:                           MLE   Df Model:                           18
# Date:                Tue, 15 Nov 2022   Pseudo R-squ.:                  0.8079
# Time:                        18:24:52   Log-Likelihood:                -4111.0
# converged:                       True   LL-Null:                       -21401.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# esent                4.0869      0.056     73.618      0.000       3.978       4.196
# eopenrate           -0.1190      0.035     -3.375      0.001      -0.188      -0.050
# eclickrate           0.1015      0.034      3.020      0.003       0.036       0.167
# avgorder            -0.1410      0.033     -4.218      0.000      -0.206      -0.075
# ordfreq              0.8946      0.288      3.104      0.002       0.330       1.459
# paperless            0.1374      0.074      1.864      0.062      -0.007       0.282
# refill               1.5841      0.130     12.195      0.000       1.329       1.839
# doorstep             2.0949      0.201     10.430      0.000       1.701       2.489
# create_first        -0.5497      0.035    -15.567      0.000      -0.619      -0.480
# first_last          -0.4783      0.040    -11.934      0.000      -0.557      -0.400
# favday_Monday        0.7415      0.087      8.539      0.000       0.571       0.912
# favday_Saturday      1.8029      0.168     10.730      0.000       1.474       2.132
# favday_Sunday        1.8279      0.247      7.414      0.000       1.345       2.311
# favday_Thursday      1.0809      0.090     11.979      0.000       0.904       1.258
# favday_Tuesday       0.8436      0.086      9.866      0.000       0.676       1.011
# favday_Wednesday     1.0751      0.097     11.068      0.000       0.885       1.266
# city_BOM             1.3478      0.080     16.947      0.000       1.192       1.504
# city_DEL             1.7741      0.086     20.697      0.000       1.606       1.942
# city_MAA             0.9664      0.088     10.984      0.000       0.794       1.139
# ====================================================================================

# %%
odds = pd.DataFrame((np.exp(log_reg.params)),index = xtrain.columns,columns=['ODDS'])
odds
# Out:
#                        ODDS
# esent             59.557523
# eopenrate          0.887837
# eclickrate         1.106863
# avgorder           0.868497
# ordfreq            2.446352
# paperless          1.147283
# refill             4.874829
# doorstep           8.124864
# create_first       0.577129
# first_last         0.619854
# favday_Monday      2.098987
# favday_Saturday    6.067234
# favday_Sunday      6.221111
# favday_Thursday    2.947413
# favday_Tuesday     2.324726
# favday_Wednesday   2.930398
# city_BOM           3.848974
# city_DEL           5.895074
# city_MAA           2.628410

# %%
ypred = log_reg.predict(xtest) # predecting the value
ypred = [1 if i > 0.5 else 0 for i in ypred]

# %%
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.90      0.79      1865
#            1       0.97      0.90      0.94      7360
#
#     accuracy                           0.90      9225
#    macro avg       0.84      0.90      0.86      9225
# weighted avg       0.92      0.90      0.91      9225

# %%
cm = confusion_matrix(ytest,ypred)
# label the confusion matrix  
# pass the matrix as 'data'
# pass the required column names to the parameter, 'columns'
# pass the required row names to the parameter, 'index'
conf_matrix = pd.DataFrame(data = cm,columns = ['Predicted churn: No','Predicted churn: Yes'], 
                           index = ['Actual churn :No','Actual churn :Yes'])

# plot a heatmap to visualize the confusion matrix
# 'annot' prints the value of each grid 
# 'fmt = d' returns the integer value in each grid
# 'cmap' assigns color to each grid
# as we do not require different colors for each grid in the heatmap,
# 'cbar = False' will not return the color bar to the right side of the heatmap
# 'linewidths' assigns the width to the line that divides each grid
# 'annot_kws = {'size':25})' assigns the font size of the annotated text 
sns.heatmap(conf_matrix, annot = True, fmt = 'd', cbar = False, 
            linewidths = 0.1, annot_kws = {'size':25})

# set the font size of x-axis ticks using 'fontsize'
plt.xticks(fontsize = 10)

# set the font size of y-axis ticks using 'fontsize'
plt.yticks(fontsize = 10)

# display the plot
plt.show()

# %%
cp =classification_report(ytest,ypred).split()
cp[5],cp[6],cp[7]
# Out:
# ('0.70', '0.90', '0.79')

# %%
cp
# Out:
# ['precision',
#  'recall',
#  'f1-score',
#  'support',
#  '0',
#  '0.70',
#  '0.90',
#  '0.79',
#  '1865',
#  '1',
#  '0.97',
#  '0.90',
#  '0.94',
#  '7360',
#  'accuracy',
#  '0.90',
#  '9225',
#  'macro',
#  'avg',
#  '0.84',
#  '0.90',
#  '0.86',
#  '9225',
#  'weighted',
#  'avg',
#  '0.92',
#  '0.90',
#  '0.91',
#  '9225']

# %%
metrics_df = pd.DataFrame([cp[5],cp[6],cp[7],round(accuracy_score(ytest,ypred),3),round(roc_auc_score(ytest,ypred),3)],
                          index=['Churn_precision','Churn_recall','Churn_f1score','Accuracy','Roc_Auc_Score'],
                         columns=['Base_model']).T
metrics_df
# Out:
#            Churn_precision Churn_recall Churn_f1score Accuracy Roc_Auc_Score
# Base_model            0.70         0.90          0.79    0.902         0.903

# %%
## To find the multicollineartity present in the datasets we will use vif

# %% [markdown]
# ## VIF

# %%
vif = [variance_inflation_factor(xtrain_bal.values,i) for i in range(xtrain_bal.shape[1])]

# %%
vif_df = pd.DataFrame({'Features':xtrain_bal.columns,'VIF':vif})
vif_df.sort_values('VIF',ascending=False)
# Out:
#             Features       VIF
# 5          paperless  2.760204
# 16          city_BOM  2.713546
# 17          city_DEL  2.555723
# 18          city_MAA  2.511845
# 10     favday_Monday  1.901113
# 14    favday_Tuesday  1.831598
# 0              esent  1.781733
# 1          eopenrate  1.718285
# 15  favday_Wednesday  1.666793
# 2         eclickrate  1.664925
# 13   favday_Thursday  1.635623
# 9         first_last  1.317455
# 4            ordfreq  1.310845
# 12     favday_Sunday  1.213729
# 6             refill  1.194474
# 8       create_first  1.161571
# 7           doorstep  1.132647
# 11   favday_Saturday  1.118166
# 3           avgorder  1.117228

# %%
# As the value of every feature is less than the 5 we can say that the presence of multicollinearty is not present

# %% [markdown]
# ## Feature Selection

# %%
LR = LogisticRegression()

# %%
## RFE SElection
rfe = RFE(estimator=LR).fit(xtrain_bal,ytrain_bal)

feature_ranking = pd.DataFrame([xtrain_bal.columns,rfe.ranking_],index=['Feature','Ranking']).T
rfe_feat=feature_ranking[feature_ranking.Ranking==1]
rfe_feat.Feature
# Out:
# 0               esent
# 4             ordfreq
# 6              refill
# 7            doorstep
# 8        create_first
# 9          first_last
# 11    favday_Saturday
# 12      favday_Sunday
# 17           city_DEL
# Name: Feature, dtype: object

# %%
feature_ranking.sort_values('Ranking').reset_index()
# Out:
#     index           Feature Ranking
# 0       0             esent       1
# 1      12     favday_Sunday       1
# 2      11   favday_Saturday       1
# 3      17          city_DEL       1
# 4       8      create_first       1
# 5       7          doorstep       1
# 6       9        first_last       1
# 7       4           ordfreq       1
# 8       6            refill       1
# 9      15  favday_Wednesday       2
# 10     13   favday_Thursday       3
# 11     14    favday_Tuesday       4
# 12     10     favday_Monday       5
# 13     16          city_BOM       6
# 14     18          city_MAA       7
# 15      3          avgorder       8
# 16      1         eopenrate       9
# 17      2        eclickrate      10
# 18      5         paperless      11

# %%
x = xtrain_bal[rfe_feat.Feature]
y= ytrain_bal

rfe_reg = sm.Logit(y,x).fit()
print(rfe_reg.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.173057
#          Iterations 8
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               retained   No. Observations:                30895
# Model:                          Logit   Df Residuals:                    30886
# Method:                           MLE   Df Model:                            8
# Date:                Fri, 18 Nov 2022   Pseudo R-squ.:                  0.7502
# Time:                        20:19:51   Log-Likelihood:                -5346.6
# converged:                       True   LL-Null:                       -21401.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# esent               3.7050      0.046     81.267      0.000       3.616       3.794
# ordfreq             5.6659      0.326     17.380      0.000       5.027       6.305
# refill              2.3506      0.116     20.191      0.000       2.122       2.579
# doorstep            2.7554      0.189     14.557      0.000       2.384       3.126
# create_first       -0.5596      0.029    -19.547      0.000      -0.616      -0.503
# first_last         -0.8910      0.033    -27.408      0.000      -0.955      -0.827
# favday_Saturday     1.8592      0.150     12.375      0.000       1.565       2.154
# favday_Sunday       2.2947      0.205     11.197      0.000       1.893       2.696
# city_DEL            1.9863      0.062     32.097      0.000       1.865       2.108
# ===================================================================================

# %%
rfe_ypred_test = rfe_reg.predict(xtest[rfe_feat.Feature])
rfe_ypred_test = [1 if i > 0.5 else 0 for i in rfe_ypred_test]
cm_1 = confusion_matrix(ytest,rfe_ypred_test)
print('Confusion Matrix:',cm_1)
sns.heatmap(cm_1,annot=True,cbar=False,fmt='d');
# Out:
# Confusion Matrix: [[1728  137]
#  [1020 6340]]

# %%
print('RFE Feature selected Logistic Regression:')
print(classification_report(ytest,rfe_ypred_test))
print('Cohen Kappa Score:',round(cohen_kappa_score(ytest,rfe_ypred_test),2))
print('ROC AUC Score:',round(roc_auc_score(ytest,rfe_ypred_test),3))
# Out:
# RFE Feature selected Logistic Regression:
#               precision    recall  f1-score   support
#
#            0       0.63      0.93      0.75      1865
#            1       0.98      0.86      0.92      7360
#
#     accuracy                           0.87      9225
#    macro avg       0.80      0.89      0.83      9225
# weighted avg       0.91      0.87      0.88      9225
#
# Cohen Kappa Score: 0.67
# ROC AUC Score: 0.894

# %%
# The model using rfe features selection gave best result than forward and backward selection techniques

# %%
fpr,tpr,th = roc_curve(ytest,rfe_reg.predict(xtest[rfe_feat.Feature]))
print('ROC AUC Score:',round(roc_auc_score(ytest,rfe_ypred_test),3))
plt.plot(fpr,tpr)
plt.plot([0,1],[0,1],'r--')
plt.show()
# Out:
# ROC AUC Score: 0.894

# %%
log_rfe = LogisticRegression().fit(xtrain_bal[rfe_feat.Feature],ytrain_bal)

# %%
cp = classification_report(ytest,rfe_ypred_test).split()
metrics_df1 = pd.DataFrame([cp[5],cp[6],cp[7],round(accuracy_score(ytest,rfe_ypred_test),3),round(roc_auc_score(ytest,rfe_ypred_test),3)],
                          index=['Churn_precision','Churn_recall','Churn_f1score','Accuracy','Roc_Auc_Score'],
                         columns=['Rfe_Features_model']).T

metrics_df2 = pd.concat([metrics_df,metrics_df1],axis=0)
metrics_df2
# Out:
#                    Churn_precision Churn_recall Churn_f1score Accuracy  \
# Base_model                    0.70         0.90          0.79    0.902
# Rfe_Features_model            0.63         0.93          0.75    0.875
#
#                    Roc_Auc_Score
# Base_model                 0.903
# Rfe_Features_model         0.894

# %% [markdown]
# ## Decision Tree

# %%
dt = DecisionTreeClassifier()

# %% [markdown]
# #### Hyperparamter Tuning

# %%
params = {'max_depth':[3,4,5],
    'min_samples_split':[2,3,4],
    'min_samples_leaf':[1,2,3],
    'max_leaf_nodes':[13,14,15]}

dt_grid = GridSearchCV(dt,param_grid=params,scoring='accuracy',n_jobs=-1)
dt_grid.fit(xtrain_bal,ytrain_bal)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [3, 4, 5], 'max_leaf_nodes': [13, 14, 15],
#                          'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 3, 4]},
#              scoring='accuracy')

# %%
dt_grid.best_params_
# Out:
# {'max_depth': 5,
#  'max_leaf_nodes': 15,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2}

# %%
tuned_mod = DecisionTreeClassifier(criterion= 'gini', max_depth =  4, max_leaf_nodes =  14, 
                                   min_samples_leaf =  1, min_samples_split =  2)

# %%
tuned_mod.fit(xtrain_bal,ytrain_bal)
# Out:
# DecisionTreeClassifier(max_depth=4, max_leaf_nodes=14)

# %%
ypred_tuned = tuned_mod.predict(xtest)

# %%
feat_imp = pd.DataFrame({'Features':xtest.columns,'Importance':tuned_mod.feature_importances_}).sort_values('Importance',ascending=False)
feat_imp[feat_imp.Importance!=0]
# Out:
#        Features  Importance
# 0         esent    0.964989
# 8  create_first    0.010854
# 5     paperless    0.009338
# 1     eopenrate    0.008446
# 3      avgorder    0.005152
# 6        refill    0.001074
# 9    first_last    0.000146

# %%
cm_2 = confusion_matrix(ytest,ypred_tuned)
print('Confusion Matrix:',cm_2)
sns.heatmap(cm_2,annot=True,cbar=False,fmt='d');
# Out:
# Confusion Matrix: [[1686  179]
#  [ 693 6667]]

# %%
print('Decision Tree:')
print(classification_report(ytest,ypred_tuned))
print('Cohen Kappa Score:',round(cohen_kappa_score(ytest,ypred_tuned),3))
print('ROC AUC Score:',round(roc_auc_score(ytest,tuned_mod.predict_proba(xtest)[:,1]),2))
# Out:
# Decision Tree:
#               precision    recall  f1-score   support
#
#            0       0.71      0.90      0.79      1865
#            1       0.97      0.91      0.94      7360
#
#     accuracy                           0.91      9225
#    macro avg       0.84      0.90      0.87      9225
# weighted avg       0.92      0.91      0.91      9225
#
# Cohen Kappa Score: 0.734
# ROC AUC Score: 0.94

# %%
from sklearn import tree

# %%
#Plot the decision tree
fig = plt.figure(figsize=(45,50))
_ = tree.plot_tree(tuned_mod,
                   feature_names=xtrain_bal.columns,  
                   class_names=['No','Yes'],
                   filled=True)

# %%
print('Cohen Kappa Score:',round(cohen_kappa_score(ytest,ypred_tuned),2))
# Out:
# Cohen Kappa Score: 0.73

# %%
plot_roc_curve(estimator=tuned_mod,X= xtest,y= ytest)
plt.plot([0,1],[0,1],'r--')
plt.show()

# %%
cp = classification_report(ytest,ypred_tuned).split()
metrics_df3 = pd.DataFrame([cp[5],cp[6],cp[7],round(accuracy_score(ytest,ypred_tuned),3),round(roc_auc_score(ytest,ypred_tuned),3)],
                          index=['Churn_precision','Churn_recall','Churn_f1score','Accuracy','Roc_Auc_Score'],
                         columns=['Decision_Tree']).T

metrics_df2 = pd.concat([metrics_df2,metrics_df3],axis=0)
metrics_df2
# Out:
#                    Churn_precision Churn_recall Churn_f1score Accuracy  \
# Base_model                    0.70         0.90          0.79    0.902
# Rfe_Features_model            0.63         0.93          0.75    0.875
# Decision_Tree                 0.71         0.90          0.79    0.905
#
#                    Roc_Auc_Score
# Base_model                 0.903
# Rfe_Features_model         0.894
# Decision_Tree              0.905

# %% [markdown]
# ### Random Forest

# %%
rf = RandomForestClassifier(n_estimators=250)

# %%
params = {'max_depth':np.arange(30,50,5)}

# %%
rf_grid = GridSearchCV(estimator=rf,param_grid=params,cv=5,n_jobs=-1)
rf_grid.fit(xtrain_bal,ytrain_bal)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(n_estimators=250),
#              n_jobs=-1, param_grid={'max_depth': array([30, 35, 40, 45])})

# %%
rf_grid.best_params_
# Out:
# {'max_depth': 30}

# %%
rf_tuned = RandomForestClassifier(n_estimators=250,max_depth=30).fit(xtrain_bal,ytrain_bal)

# %%
print('Random Forest:')
rf_ypred = rf_tuned.predict(xtest)
print(classification_report(ytest,rf_ypred))
print("Cohen Kappa Score:",round(cohen_kappa_score(rf_ypred,ytest),3))
# Out:
# Random Forest:
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86      1865
#            1       0.97      0.95      0.96      7360
#
#     accuracy                           0.94      9225
#    macro avg       0.90      0.93      0.91      9225
# weighted avg       0.95      0.94      0.94      9225
#
# Cohen Kappa Score: 0.828

# %%
sns.heatmap(confusion_matrix(ytest,rf_ypred),annot=True,fmt='d',cbar=False,cmap='Blues');

# %%
plot_roc_curve(estimator=rf_tuned, X = xtest, y = ytest)
plt.plot([0,1],[0,1],'r--')
plt.show()

# %%
cp = classification_report(ytest,rf_ypred).split()
metrics_df4 = pd.DataFrame([cp[5],cp[6],cp[7],round(accuracy_score(ytest,rf_ypred),3),round(roc_auc_score(ytest,rf_ypred),3)],
                          index=['Churn_precision','Churn_recall','Churn_f1score','Accuracy','Roc_Auc_Score'],
                         columns=['Random_Forest']).T

metrics_df2 = pd.concat([metrics_df2,metrics_df4],axis=0)
metrics_df2
# Out:
#                    Churn_precision Churn_recall Churn_f1score Accuracy  \
# Base_model                    0.70         0.90          0.79    0.902
# Rfe_Features_model            0.63         0.93          0.75    0.875
# Decision_Tree                 0.71         0.90          0.79    0.905
# Random_Forest                 0.83         0.90          0.86    0.943
#
#                    Roc_Auc_Score
# Base_model                 0.903
# Rfe_Features_model         0.894
# Decision_Tree              0.905
# Random_Forest              0.928

# %% [markdown]
# ## Boosting

# %% [markdown]
# ### 1.Adaboost

# %%
adaboost = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(),n_estimators=50)

# %%
adaboost.fit(xtrain_bal,ytrain_bal)
# Out:
# AdaBoostClassifier(base_estimator=DecisionTreeClassifier())

# %%
ypred_prob = adaboost.predict_proba(xtest)[:,1]

# %%
ypred = adaboost.predict(xtest)

# %%
print('Adaboost:')
print(classification_report(ytest,ypred))
print('Cohen Kappa Score:',round(cohen_kappa_score(ytest,ypred),2))
# Out:
# Adaboost:
#               precision    recall  f1-score   support
#
#            0       0.60      0.91      0.72      1865
#            1       0.97      0.84      0.90      7360
#
#     accuracy                           0.86      9225
#    macro avg       0.79      0.88      0.81      9225
# weighted avg       0.90      0.86      0.87      9225
#
# Cohen Kappa Score: 0.63

# %%
sns.heatmap(confusion_matrix(ytest,ypred),annot=True,fmt='d',cbar=False,cmap='Blues');

# %%
fpr,tpr,th = roc_curve(ytest,ypred_prob)

# %%
plot_roc_curve(estimator=adaboost,X=xtest,y=ytest)
plt.plot([0,1],[0,1],'r--')
plt.show()

# %%
cp = classification_report(ytest,ypred).split()
metrics_df5 = pd.DataFrame([cp[5],cp[6],cp[7],round(accuracy_score(ytest,ypred),3),round(roc_auc_score(ytest,ypred),3)],
                          index=['Churn_precision','Churn_recall','Churn_f1score','Accuracy','Roc_Auc_Score'],
                         columns=['AdaBoost']).T

metrics_df2 = pd.concat([metrics_df2,metrics_df5],axis=0)
metrics_df2
# Out:
#                    Churn_precision Churn_recall Churn_f1score Accuracy  \
# Base_model                    0.70         0.90          0.79    0.902
# Rfe_Features_model            0.63         0.93          0.75    0.875
# Decision_Tree                 0.71         0.90          0.79    0.905
# Random_Forest                 0.83         0.90          0.86    0.943
# AdaBoost                      0.60         0.91          0.72    0.858
#
#                    Roc_Auc_Score
# Base_model                 0.903
# Rfe_Features_model         0.894
# Decision_Tree              0.905
# Random_Forest              0.928
# AdaBoost                   0.877

# %% [markdown]
# ### 2. XG Boost

# %%
xgb = XGBClassifier(gamma=1)

# %%
xgb.fit(xtrain_bal,ytrain_bal)
# Out:
# [12:47:23] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=1, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=4,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
ypred =xgb.predict(xtest)
ypred_prob = xgb.predict_proba(xtest)[:,1]

# %%
sns.heatmap(confusion_matrix(ytest,ypred),annot=True,fmt='d',cbar=False,cmap='Blues');

# %%
print('XG Boost')
print(classification_report(ytest,ypred))
print('COhen Kappa Score:',round(cohen_kappa_score(ytest,ypred),2))
# Out:
# XG Boost
#               precision    recall  f1-score   support
#
#            0       0.72      0.94      0.81      1865
#            1       0.98      0.91      0.94      7360
#
#     accuracy                           0.91      9225
#    macro avg       0.85      0.92      0.88      9225
# weighted avg       0.93      0.91      0.92      9225
#
# COhen Kappa Score: 0.76

# %%
fpr,tpr,th = roc_curve(ytest,ypred_prob)

# %%
plot_roc_curve(estimator=xgb,X=xtest,y=ytest)
plt.plot([0,1],[0,1],'r--')
plt.show()

# %%
cp = classification_report(ytest,ypred).split()
metrics_df6 = pd.DataFrame([cp[5],cp[6],cp[7],round(accuracy_score(ytest,ypred),3),round(roc_auc_score(ytest,ypred),3)],
                          index=['Churn_precision','Churn_recall','Churn_f1score','Accuracy','Roc_Auc_Score'],
                         columns=['XGBoost']).T

metrics_df2 = pd.concat([metrics_df2,metrics_df6],axis=0)
metrics_df2
# Out:
#                    Churn_precision Churn_recall Churn_f1score Accuracy  \
# Base_model                    0.70         0.90          0.79    0.902
# Rfe_Features_model            0.63         0.93          0.75    0.875
# Decision_Tree                 0.71         0.90          0.79    0.905
# Random_Forest                 0.83         0.90          0.86    0.943
# AdaBoost                      0.60         0.91          0.72    0.858
# XGBoost                       0.72         0.94          0.81    0.913
#
#                    Roc_Auc_Score
# Base_model                 0.903
# Rfe_Features_model         0.894
# Decision_Tree              0.905
# Random_Forest              0.928
# AdaBoost                   0.877
# XGBoost                    0.922

# %% [markdown]
# ## Stacking

# %%
base = [('dt',DecisionTreeClassifier()),('rf',RandomForestClassifier())]
stack_mod = StackingClassifier(estimators=base,final_estimator=AdaBoostClassifier())
stack_mod.fit(xtrain_bal,ytrain_bal)
# Out:
# StackingClassifier(estimators=[('dt', DecisionTreeClassifier()),
#                                ('rf', RandomForestClassifier())],
#                    final_estimator=AdaBoostClassifier())

# %%
ypred = stack_mod.predict(xtest)

# %%
print('Stacking:')
print(classification_report(ytest,ypred))
print('Cohen Kappa Score',round(cohen_kappa_score(ytest,ypred),2))
# Out:
# Stacking:
#               precision    recall  f1-score   support
#
#            0       0.80      0.91      0.85      1865
#            1       0.98      0.94      0.96      7360
#
#     accuracy                           0.94      9225
#    macro avg       0.89      0.93      0.91      9225
# weighted avg       0.94      0.94      0.94      9225
#
# Cohen Kappa Score 0.81

# %%
plot_roc_curve(estimator=stack_mod,X=xtest,y=ytest)
plt.plot([0,1],[0,1],'r--')

# %%
sns.heatmap(confusion_matrix(ytest,ypred),annot=True,fmt='d',cbar=False,cmap='Blues');

# %%
cp = classification_report(ytest,ypred).split()
metrics_df7 = pd.DataFrame([cp[5],cp[6],cp[7],round(accuracy_score(ytest,ypred),3),round(roc_auc_score(ytest,ypred),3)],
                          index=['Churn_precision','Churn_recall','Churn_f1score','Accuracy','Roc_Auc_Score'],
                         columns=['Stacking_Reg']).T

metrics_df2 = pd.concat([metrics_df2,metrics_df7],axis=0)
metrics_df2
# Out:
#                    Churn_precision Churn_recall Churn_f1score Accuracy  \
# Base_model                    0.70         0.90          0.79    0.902
# Rfe_Features_model            0.63         0.93          0.75    0.875
# Decision_Tree                 0.71         0.90          0.79    0.905
# Random_Forest                 0.83         0.90          0.86    0.943
# AdaBoost                      0.60         0.91          0.72    0.858
# XGBoost                       0.72         0.94          0.81    0.913
# Stacking_Reg                  0.80         0.91          0.85    0.936
#
#                    Roc_Auc_Score
# Base_model                 0.903
# Rfe_Features_model         0.894
# Decision_Tree              0.905
# Random_Forest              0.928
# AdaBoost                   0.877
# XGBoost                    0.922
# Stacking_Reg               0.928

# %%
metrics_df2.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# </style>
# <table id="T_fadb7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Churn_precision</th>
#       <th class="col_heading level0 col1" >Churn_recall</th>
#       <th class="col_heading level0 col2" >Churn_f1score</th>
#       <th class="col_heading level0 col3" >Accuracy</th>
#       <th class="col_heading level0 col4" >Roc_Auc_Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fadb7_level0_row0" class="row_heading level0 row0" >Base_model</th>
#       <td id="T_fadb7_row0_col0" class="data row0 col0" >0.70</td>
#       <td id="T_fadb7_row0_col1" class="data row0 col1" >0.90</td>
#       <td id="T_fadb7_row0_col2" class="data row0 col2" >0.79</td>
#       <td id="T_fadb7_row0_col3" class="data row0 col3" >0.902000</td>
#       <td id="T_fadb7_row0_col4" class="data row0 col4" >0.903000</td>
#     </tr>
#     <tr>
#       <th id="T_fadb7_level0_row1" class="row_heading level0 row1" >Rfe_Features_model</th>
#       <td id="T_fadb7_row1_col0" class="data row1 col0" >0.63</td>
#       <td id="T_fadb7_row1_col1" class="data row1 col1" >0.93</td>
#       <td id="T_fadb7_row1_col2" class="data row1 col2" >0.75</td>
#       <td id="T_fadb7_row1_col3" class="data row1 col3" >0.875000</td>
#       <td id="T_fadb7_row1_col4" class="data row1 col4" >0.894000</td>
#     </tr>
#     <tr>
#       <th id="T_fadb7_level0_row2" class="row_heading level0 row2" >Decision_Tree</th>
#       <td id="T_fadb7_row2_col0" class="data row2 col0" >0.71</td>
#       <td id="T_fadb7_row2_col1" class="data row2 col1" >0.90</td>
#       <td id="T_fadb7_row2_col2" class="data row2 col2" >0.79</td>
#       <td id="T_fadb7_row2_col3" class="data row2 col3" >0.905000</td>
#       <td id="T_fadb7_row2_col4" class="data row2 col4" >0.905000</td>
#     </tr>
#     <tr>
#       <th id="T_fadb7_level0_row3" class="row_heading level0 row3" >Random_Forest</th>
#       <td id="T_fadb7_row3_col0" class="data row3 col0" >0.83</td>
#       <td id="T_fadb7_row3_col1" class="data row3 col1" >0.90</td>
#       <td id="T_fadb7_row3_col2" class="data row3 col2" >0.86</td>
#       <td id="T_fadb7_row3_col3" class="data row3 col3" >0.943000</td>
#       <td id="T_fadb7_row3_col4" class="data row3 col4" >0.928000</td>
#     </tr>
#     <tr>
#       <th id="T_fadb7_level0_row4" class="row_heading level0 row4" >AdaBoost</th>
#       <td id="T_fadb7_row4_col0" class="data row4 col0" >0.60</td>
#       <td id="T_fadb7_row4_col1" class="data row4 col1" >0.91</td>
#       <td id="T_fadb7_row4_col2" class="data row4 col2" >0.72</td>
#       <td id="T_fadb7_row4_col3" class="data row4 col3" >0.858000</td>
#       <td id="T_fadb7_row4_col4" class="data row4 col4" >0.877000</td>
#     </tr>
#     <tr>
#       <th id="T_fadb7_level0_row5" class="row_heading level0 row5" >XGBoost</th>
#       <td id="T_fadb7_row5_col0" class="data row5 col0" >0.72</td>
#       <td id="T_fadb7_row5_col1" class="data row5 col1" >0.94</td>
#       <td id="T_fadb7_row5_col2" class="data row5 col2" >0.81</td>
#       <td id="T_fadb7_row5_col3" class="data row5 col3" >0.913000</td>
#       <td id="T_fadb7_row5_col4" class="data row5 col4" >0.922000</td>
#     </tr>
#     <tr>
#       <th id="T_fadb7_level0_row6" class="row_heading level0 row6" >Stacking_Reg</th>
#       <td id="T_fadb7_row6_col0" class="data row6 col0" >0.80</td>
#       <td id="T_fadb7_row6_col1" class="data row6 col1" >0.91</td>
#       <td id="T_fadb7_row6_col2" class="data row6 col2" >0.85</td>
#       <td id="T_fadb7_row6_col3" class="data row6 col3" >0.936000</td>
#       <td id="T_fadb7_row6_col4" class="data row6 col4" >0.928000</td>
#     </tr>
#   </tbody>
# </table>

# %%
metrics_df2.style.highlight_max()
# Out:
# <style type="text/css">
# #T_87350_row3_col0, #T_87350_row3_col2, #T_87350_row3_col3, #T_87350_row3_col4, #T_87350_row5_col1, #T_87350_row6_col4 {
#   background-color: yellow;
# }
# </style>
# <table id="T_87350_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Churn_precision</th>
#       <th class="col_heading level0 col1" >Churn_recall</th>
#       <th class="col_heading level0 col2" >Churn_f1score</th>
#       <th class="col_heading level0 col3" >Accuracy</th>
#       <th class="col_heading level0 col4" >Roc_Auc_Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87350_level0_row0" class="row_heading level0 row0" >Base_model</th>
#       <td id="T_87350_row0_col0" class="data row0 col0" >0.70</td>
#       <td id="T_87350_row0_col1" class="data row0 col1" >0.90</td>
#       <td id="T_87350_row0_col2" class="data row0 col2" >0.79</td>
#       <td id="T_87350_row0_col3" class="data row0 col3" >0.902000</td>
#       <td id="T_87350_row0_col4" class="data row0 col4" >0.903000</td>
#     </tr>
#     <tr>
#       <th id="T_87350_level0_row1" class="row_heading level0 row1" >Rfe_Features_model</th>
#       <td id="T_87350_row1_col0" class="data row1 col0" >0.63</td>
#       <td id="T_87350_row1_col1" class="data row1 col1" >0.93</td>
#       <td id="T_87350_row1_col2" class="data row1 col2" >0.75</td>
#       <td id="T_87350_row1_col3" class="data row1 col3" >0.875000</td>
#       <td id="T_87350_row1_col4" class="data row1 col4" >0.894000</td>
#     </tr>
#     <tr>
#       <th id="T_87350_level0_row2" class="row_heading level0 row2" >Decision_Tree</th>
#       <td id="T_87350_row2_col0" class="data row2 col0" >0.71</td>
#       <td id="T_87350_row2_col1" class="data row2 col1" >0.90</td>
#       <td id="T_87350_row2_col2" class="data row2 col2" >0.79</td>
#       <td id="T_87350_row2_col3" class="data row2 col3" >0.905000</td>
#       <td id="T_87350_row2_col4" class="data row2 col4" >0.905000</td>
#     </tr>
#     <tr>
#       <th id="T_87350_level0_row3" class="row_heading level0 row3" >Random_Forest</th>
#       <td id="T_87350_row3_col0" class="data row3 col0" >0.83</td>
#       <td id="T_87350_row3_col1" class="data row3 col1" >0.90</td>
#       <td id="T_87350_row3_col2" class="data row3 col2" >0.86</td>
#       <td id="T_87350_row3_col3" class="data row3 col3" >0.943000</td>
#       <td id="T_87350_row3_col4" class="data row3 col4" >0.928000</td>
#     </tr>
#     <tr>
#       <th id="T_87350_level0_row4" class="row_heading level0 row4" >AdaBoost</th>
#       <td id="T_87350_row4_col0" class="data row4 col0" >0.60</td>
#       <td id="T_87350_row4_col1" class="data row4 col1" >0.91</td>
#       <td id="T_87350_row4_col2" class="data row4 col2" >0.72</td>
#       <td id="T_87350_row4_col3" class="data row4 col3" >0.858000</td>
#       <td id="T_87350_row4_col4" class="data row4 col4" >0.877000</td>
#     </tr>
#     <tr>
#       <th id="T_87350_level0_row5" class="row_heading level0 row5" >XGBoost</th>
#       <td id="T_87350_row5_col0" class="data row5 col0" >0.72</td>
#       <td id="T_87350_row5_col1" class="data row5 col1" >0.94</td>
#       <td id="T_87350_row5_col2" class="data row5 col2" >0.81</td>
#       <td id="T_87350_row5_col3" class="data row5 col3" >0.913000</td>
#       <td id="T_87350_row5_col4" class="data row5 col4" >0.922000</td>
#     </tr>
#     <tr>
#       <th id="T_87350_level0_row6" class="row_heading level0 row6" >Stacking_Reg</th>
#       <td id="T_87350_row6_col0" class="data row6 col0" >0.80</td>
#       <td id="T_87350_row6_col1" class="data row6 col1" >0.91</td>
#       <td id="T_87350_row6_col2" class="data row6 col2" >0.85</td>
#       <td id="T_87350_row6_col3" class="data row6 col3" >0.936000</td>
#       <td id="T_87350_row6_col4" class="data row6 col4" >0.928000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The random forest, decision tree, XG boost and stacking are best in terms of prediction accuracy for the given dataset.
# Target Email campaign for the existing customers will increase customer retention rate.
# Faster 2-day delivery is an effective way to increase customer retention rate.
# By using the Random forest model we can predict the churn rate with an accuracy of 94.3%
